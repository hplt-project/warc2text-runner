# %%
import pandas as pd

# %% [markdown]
# # For a 0.001% sample of WP2 outputs for data release 2:
# ### load urls and detected languages

# %%
# !for x in ../../sample0.01_sample0.001/*; do zstdcat $x/all.zst|jq -c '{"lang":.lang,"u":.u}' |zstd>$x/url_lang.zst; done

# %%
from pathlib import Path
dfs = []
for p in Path('../../sample0.01_sample0.001/').glob('*/url_lang.zst'):
    df = pd.read_json(p, lines=True, encoding_errors='ignore')
    df['crawl'] = p.parent.name
    dfs.append(df)
#     break
df = pd.concat(dfs, ignore_index=True)

# %%
len(df)
# Out:
# 1055157

# %%
df.head()
# Out:
#        lang                                                  u  \
# 0  spa_Latn  http://academia.org.mx/academicos-2001/item/ma...
# 1  eng_Latn  http://aftek.com/testingservices/testjig%20arc...
# 2      None  http://albany.upickem.net/engine/Welcome.aspx?...
# 3  jpn_Jpan  http://allinfor.ga/468217yuasa-pe2dd_qa9bdd_q4...
# 4  ita_Latn  http://carirac.com/differenze/honda-logo-opel-...
#
#              crawl
# 0  CC-MAIN-2018-26
# 1  CC-MAIN-2018-26
# 2  CC-MAIN-2018-26
# 3  CC-MAIN-2018-26
# 4  CC-MAIN-2018-26

# %% [markdown]
# ### Split urls into parts

# %%
df['site'] = df.u.str.split('//').str[-1].str.split('/').str[0]
df['tld'] = df.site.str.split('.').str[-1]
df['domain'] = df.site.str.split('.').str[-2]
df
# Out:
#              lang                                                  u  \
# 0        spa_Latn  http://academia.org.mx/academicos-2001/item/ma...
# 1        eng_Latn  http://aftek.com/testingservices/testjig%20arc...
# 2            None  http://albany.upickem.net/engine/Welcome.aspx?...
# 3        jpn_Jpan  http://allinfor.ga/468217yuasa-pe2dd_qa9bdd_q4...
# 4        ita_Latn  http://carirac.com/differenze/honda-logo-opel-...
# ...           ...                                                ...
# 1055152  ita_Latn        https://www.svapofone.com/tag-prodotto/g25/
# 1055153  eng_Latn  https://www.theyucatantimes.com/2021/11/exclus...
# 1055154  eng_Latn  https://www.urbandictionary.com/define.php?ter...
# 1055155  ita_Latn  https://www.visititaly.ch/fiera-turistica-a-be...
# 1055156  zho_Hans  https://zhejiudao.com/e/tags/?tagname=%E9%99%8...
#
#                    crawl                     site  tld           domain
# 0        CC-MAIN-2018-26          academia.org.mx   mx              org
# 1        CC-MAIN-2018-26                aftek.com  com            aftek
# 2        CC-MAIN-2018-26       albany.upickem.net  net          upickem
# 3        CC-MAIN-2018-26              allinfor.ga   ga         allinfor
# 4        CC-MAIN-2018-26              carirac.com  com          carirac
# ...                  ...                      ...  ...              ...
# 1055152  CC-MAIN-2022-49        www.svapofone.com  com        svapofone
# 1055153  CC-MAIN-2022-49  www.theyucatantimes.com  com  theyucatantimes
# 1055154  CC-MAIN-2022-49  www.urbandictionary.com  com  urbandictionary
# 1055155  CC-MAIN-2022-49        www.visititaly.ch   ch       visititaly
# 1055156  CC-MAIN-2022-49            zhejiudao.com  com        zhejiudao
#
# [1055157 rows x 6 columns]

# %% [markdown]
# ### look at most/least frequent langauges and TLDs

# %%
lang_cnts = df.lang.value_counts().head(50)
lang_cnts
# Out:
# eng_Latn    404169
# zho_Hans    123171
# rus_Cyrl     63778
# deu_Latn     37568
# jpn_Jpan     30682
# spa_Latn     26790
# fra_Latn     25277
# por_Latn     18504
# pol_Latn     17658
# zho_Hant     16805
# nld_Latn     16383
# ita_Latn     14150
# zsm_Latn     13571
# jav_Latn     11511
# mlt_Latn     10152
# swe_Latn      9908
# tur_Latn      9248
# pes_Arab      7472
# dan_Latn      7123
# vie_Latn      7011
# zul_Latn      6722
# nno_Latn      6232
# arb_Arab      6179
# kor_Hang      5957
# ces_Latn      5730
# ind_Latn      4996
# cat_Latn      4853
# hun_Latn      4807
# ell_Grek      4444
# ron_Latn      4273
# slk_Latn      3594
# ilo_Latn      3261
# fin_Latn      3041
# tha_Thai      2950
# lvs_Latn      2841
# nob_Latn      2550
# ukr_Cyrl      2508
# hat_Latn      2410
# hrv_Latn      2299
# bul_Cyrl      2258
# vec_Latn      2135
# srd_Latn      1985
# lit_Latn      1892
# arz_Arab      1868
# lim_Latn      1801
# est_Latn      1781
# slv_Latn      1746
# grn_Latn      1612
# heb_Hebr      1556
# prs_Arab      1275
# Name: lang, dtype: int64

# %%
lang_cnts = df.lang.value_counts().tail(25)
lang_cnts
# Out:
# snd_Arab    9
# shn_Mymr    8
# san_Deva    8
# fij_Latn    8
# lua_Latn    8
# cjk_Latn    7
# kmb_Latn    7
# kas_Arab    7
# mos_Latn    7
# dik_Latn    7
# asm_Beng    5
# kik_Latn    4
# umb_Latn    4
# mai_Deva    4
# tum_Latn    4
# sot_Latn    4
# tir_Ethi    4
# kas_Deva    3
# kam_Latn    3
# kon_Latn    2
# taq_Latn    2
# fon_Latn    2
# ace_Arab    2
# kac_Latn    1
# acq_Arab    1
# Name: lang, dtype: int64

# %%
tld_cnts = df.tld.value_counts().head(100)
tld_cnts
# Out:
# com       591681
# ru         44734
# net        43759
# org        43172
# cn         39040
#            ...
# bid          299
# name         297
# la           273
# am           260
# webcam       243
# Name: tld, Length: 100, dtype: int64

# %% [markdown]
# # Study P(tld|lang) and P(lang|tld)

# %% [markdown]
# ### for clarity leave only 50 most frequent languages and 100 most frequent TLDs

# %%
fdf = df[df.lang.isin(df.lang.value_counts().head(50).index) & df.tld.isin(df.tld.value_counts().head(100).index)]

# %%
df_langp = fdf.groupby('tld').lang.value_counts(normalize=True)
df_tldp = fdf.groupby('lang').tld.value_counts(normalize=True)
df_langp
# Out:
# tld  lang
# ae   eng_Latn    0.726027
#      arb_Arab    0.150685
#      arz_Arab    0.030822
#      nld_Latn    0.020548
#      jav_Latn    0.013699
#                    ...
# za   lit_Latn    0.000926
#      lvs_Latn    0.000926
#      rus_Cyrl    0.000926
#      slv_Latn    0.000926
#      zho_Hans    0.000926
# Name: lang, Length: 3294, dtype: float64

# %%
ldf = df_langp.to_frame().rename(columns={'lang':'P(lang|tld)'}).reset_index()
tdf = df_tldp.to_frame().rename(columns={'tld':'P(tld|lang)'}).reset_index()

qdf = ldf.merge(tdf, on=['tld','lang'], how='inner')

# %%
# Which TLDs have more than 50% of documents in a single language?
qdf[qdf["P(lang|tld)"]>0.5].sort_values(by='P(tld|lang)', ascending=False).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T
{
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_a80f7_row42_col2, #T_a80f7_row44_col3 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_a80f7_row42_col3 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_a80f7_row43_col2 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_a80f7_row43_col3 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_a80f7_row45_col2, #T_a80f7_row55_col2 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_a80f7_row45_col3, #T_a80f7_row63_col2 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_a80f7_row46_col2, #T_a80f7_row61_col2 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_a80f7_row46_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_a80f7_row47_col3, #T_a80f7_row48_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_a80f7_row48_col2 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_a80f7_row49_col3, #T_a80f7_row50_col3, #T_a80f7_row51_col3, #T_a80f7_row52_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_a80f7_row50_col2 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_a80f7_row52_col2 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_a80f7_row53_col2 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_a80f7_row53_col3, #T_a80f7_row54_col3, #T_a80f7_row55_col3, #T_a80f7_row56_col3, #T_a80f7_row57_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_a80f7_row57_col2 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_a80f7_row58_col2 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_a80f7_row58_col3, #T_a80f7_row59_col3 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_a80f7_row59_col2 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_a80f7_row60_col2 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_a80f7_row62_col2 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_a80f7_row64_col2, #T_a80f7_row69_col2 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_a80f7_row65_col2 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_a80f7_row66_col2 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_a80f7_row67_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_a80f7_row68_col2 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_a80f7_row70_col2 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_a80f7_row71_col2 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_a

# %% [markdown]
# # Select TLDs to sample from for a few languages we might be interested in labeling some data for; just to debug the data selection procedure

# %%
langs = [
    'nob_Latn', 'nno_Latn',
    'rus_Cyrl','glg_Latn','eus_Latn','cat_Latn','spa_Latn',
         'fin_Latn','ces_Latn',
    'gle_Latn', 'gla_Latn','cym_Latn',
    'est_Latn','heb_Hebr','hun_Latn','fra_Latn',
    'prs_Arab']

# %% [markdown]
# ### When selecting documents from some TLD as an approximation of selecting documents in a given language, P(lang|tld) corresponds to precision and P(tld|lang) to recall.

# %%
# tmp = qdf[qdf['P(tld|lang)']>0.1]
tmp = qdf
toptld = tmp.sort_values(by='P(lang|tld)', ascending=False).groupby('lang').apply(lambda g: g.head(3))
toptld[toptld.lang.isin(langs)].style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_90ab6_row0_col2 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_90ab6_row0_col3, #T_90ab6_row23_col2 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_90ab6_row1_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_90ab6_row1_col3, #T_90ab6_row5_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_90ab6_row2_col2, #T_90ab6_row8_col3, #T_90ab6_row20_col2, #T_90ab6_row20_col3, #T_90ab6_row22_col3, #T_90ab6_row25_col2, #T_90ab6_row31_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_90ab6_row2_col3, #T_90ab6_row5_col2, #T_90ab6_row23_col3 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_90ab6_row3_col2 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_90ab6_row3_col3, #T_90ab6_row30_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_90ab6_row4_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_90ab6_row4_col3, #T_90ab6_row7_col3, #T_90ab6_row16_col3, #T_90ab6_row17_col2, #T_90ab6_row19_col3, #T_90ab6_row25_col3, #T_90ab6_row26_col3, #T_90ab6_row28_col2, #T_90ab6_row28_col3, #T_90ab6_row29_col2, #T_90ab6_row29_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_90ab6_row6_col2 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_90ab6_row6_col3 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_90ab6_row7_col2, #T_90ab6_row8_col2, #T_90ab6_row10_col3, #T_90ab6_row16_col2, #T_90ab6_row26_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_90ab6_row9_col2 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_90ab6_row9_col3 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_90ab6_row10_col2, #T_90ab6_row21_col3 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_90ab6_row11_col2, #T_90ab6_row14_col3, #T_90ab6_row30_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_90ab6_row11_col3, #T_90ab6_row17_col3, #T_90ab6_row33_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_90ab6_row12_col2, #T_90ab6_row33_col2 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_90ab6_row12_col3 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_90ab6_row13_col2 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_90ab6_row13_col3 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_90ab6_row14_col2 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_90ab6_row15_col2 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_90ab6_row15_col3 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_90ab6_row18_col2 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_90ab6_row18_col3 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_90ab6_row19_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_90ab6_row21_col2 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_90ab6_row22_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_90ab6_row24_col2 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_90ab6_row24_col3 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_90ab6_row27_col2 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_90ab6_row27_col3 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_90ab6_row31_col2 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_90ab6_row32_col2 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_90ab6_row32_col3 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_90ab6_row34_col2 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_90ab6_row34_col3 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_90ab6_row35_col2 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_90ab6_row35_col3 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# </style>
# <table id="T_90ab6">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90ab6_level0_col0" class="col_heading level0 col0" >tld</th>
#       <th id="T_90ab6_level0_col1" class="col_heading level0 col1" >lang</th>
#       <th id="T_90ab6_level0_col2" class="col_heading level0 col2" >P(lang|tld)</th>
#       <th id="T_90ab6_level0_col3" class="col_heading level0 col3" >P(tld|lang)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >lang</th>
#       <th class="index_name level1" >&nbsp;</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90ab6_level0_row0" class="row_heading level0 row0" rowspan="3">cat_Latn</th>
#       <th id="T_90ab6_level1_row0" class="row_heading level1 row0" >439</th>
#       <td id="T_90ab6_row0_col0" class="data row0 col0" >cat</td>
#       <td id="T_90ab6_row0_col1" class="data row0 col1" >cat_Latn</td>
#       <td id="T_90ab6_row0_col2" class="data row0 col2" >0.802500</td>
#       <td id="T_90ab6_row0_col3" class="data row0 col3" >0.066681</td>
#     </tr>
#     <tr>
#       <th id="T_90ab6_level1_row1" class="row_heading level1 row1" >3172</th>
#       <td id="T_90ab6_row1_col0" class="data row1 col0" >xxx</td>
#       <td id="T_90ab6_row1_col1" class="data row1 col1" >cat_Latn</td>
#       <td id="T_90ab6_row1_col2" class="data row1 col2" >0.041573</td>
#       <td id="T_90ab6_row1_col3" class="data row1 col3" >0.023058</td>
#     </tr>
#     <tr>
#       <th id="T_90ab6_level1_row2" class="row_heading level1 row2" >975</th>
#       <td id="T_90ab6_row2_col0" class="data row2 col0" >es</td>
#       <td id="T_90ab6_row2_col1" class="data row2 col1" >cat_Latn</td>
#       <td id="T_90ab6_row2_col2" class="data row2 col2" >0.019198</td>
#       <td id="T_90ab6_row2_col3" class="data row2 col3" >0.023473</td>
#     </tr>
#     <tr>
#       <th id="T_90ab6_level0_row3" class="row_heading level0 row3" rowspan="3">ces_Latn</th>
#       <th id="T_90ab6_level1_row3" class="row_heading level1 row3" >749</th>
#       <td id="T_90ab6_row3_col0" class="data row3 col0" >cz</td>
#       <td id="T_90ab6_row3_col1" class="data row3 col1" >ces_Latn</td>
#       <td id="T_90ab6_row3_col2" class="data row3 col2" >0.806546</td>
#       <td id="T_90ab6_row3_col3" class="data row3 col3" >0.726953</td>
#     </tr>
#     <tr>
#       <th id="T_90ab6_level1_row4" class="row_heading level1 row4" >3102</th>
#       <td id="T_90ab6_row4_col0" class="data row4 col0" >webcam</td>
#       <td id="T_90ab6_row4_col1" class="data row4 col1" >ces_Latn</td>
#       <td id="T_90ab6_row4_col2" class="data row4 col2" >0.052632</td>
#       <td id="T_90ab6_row4_col3" class="data row4 col3" >0.002107</td>
#     </tr>
#     <tr>
#       <th id="T_90ab6_level1_row5" class="row_heading level1 row5" >1020</th>
#       <td id="T_90ab6_row5_col0" class="data row5 col0" >eu</td>
#       <td id="T_90ab6_row5_col1" class="data row5 col1" >ces_Latn</td>
#       <td id="T_90ab6_row5_col2" class="data row5 col2" >0.031465</td>
#       <td id="T_90ab6_row5_col3" class="data row5 col3" >0.020896</td>
#     </tr>
#     <tr>
#       <th id="T_90ab6_level0_row6" class="row_heading level0 row6" rowspan="3">est_Latn</th>
#       <th id="T_90ab6_level1_row6" class="row_heading level1 row6" >945</th>
#       <td id="T_90ab6_row6_col0" class="data row6 col0" >ee</td>
#       <td id="T_90ab6_row6_col1" class="data row6 col1" >est_Latn</td>
#       <td id="T_90ab6_row6_col2" class="data row6 col2" >0.705570</td>
#       <td id="T_90ab6_row6_col3" class="data row6 col3" >0.302445</td>
#     </tr>
#     <tr>
#       <th id="T_90ab6_level1_row7" class="row_heading level1 row7" >3133</th>
#       <td id="T_90ab6_row7_col0" class="data row7 col0" >ws</td>
#       <td id="T_90ab6_row7_col1" class="data row7 col1" >est_Latn</td>
#       <td id="T_90ab6_row7_col2" class="data row7 col2" >0.007212</td>
#       <td id="T_90ab6_row7_col3" class="data row7 col3" >0.001706</td>
#     </tr>
#     <tr>
#       <th id="T_90ab6_level1_row8" class="row_heading level1 row8" >3190</th>
#       <td id="T_90ab6_row8_col0" class="data row8 col0" >xxx</td>
#       <td id="T_90ab6_row8_col1" class="data row8 col1" >est_Latn</td>
#       <td id="T_90ab6_row8_col2" class="data row8 col2" >0.006742</td>
#       <td id="T_90ab6_row8_col3" class="data row8 col3" >0.010233</td>
#     </tr>
#     <tr>

# %%
qdf[qdf.lang.str.contains('fra_Latn')].sort_values(by="P(lang|tld)", ascending=False).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_bb4c7_row0_col2, #T_bb4c7_row15_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_bb4c7_row0_col3 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_bb4c7_row1_col2 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_bb4c7_row1_col3, #T_bb4c7_row7_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_bb4c7_row2_col2 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_bb4c7_row2_col3, #T_bb4c7_row11_col2, #T_bb4c7_row12_col2 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_bb4c7_row3_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_bb4c7_row3_col3, #T_bb4c7_row8_col2, #T_bb4c7_row9_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_bb4c7_row4_col2 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_bb4c7_row4_col3, #T_bb4c7_row5_col3, #T_bb4c7_row9_col3, #T_bb4c7_row11_col3, #T_bb4c7_row13_col3, #T_bb4c7_row14_col3, #T_bb4c7_row17_col3, #T_bb4c7_row18_col3, #T_bb4c7_row19_col3, #T_bb4c7_row20_col3, #T_bb4c7_row21_col3, #T_bb4c7_row22_col3, #T_bb4c7_row23_col3, #T_bb4c7_row24_col3, #T_bb4c7_row25_col3, #T_bb4c7_row26_col3, #T_bb4c7_row27_col3, #T_bb4c7_row28_col3, #T_bb4c7_row29_col3, #T_bb4c7_row30_col3, #T_bb4c7_row31_col3, #T_bb4c7_row32_col3, #T_bb4c7_row33_col3, #T_bb4c7_row34_col3, #T_bb4c7_row35_col3, #T_bb4c7_row36_col3, #T_bb4c7_row37_col3, #T_bb4c7_row38_col3, #T_bb4c7_row39_col3, #T_bb4c7_row40_col3, #T_bb4c7_row41_col3, #T_bb4c7_row42_col3, #T_bb4c7_row43_col2, #T_bb4c7_row43_col3, #T_bb4c7_row44_col2, #T_bb4c7_row45_col2, #T_bb4c7_row45_col3, #T_bb4c7_row46_col2, #T_bb4c7_row46_col3, #T_b
col3 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_bb4c7_row17_col2, #T_bb4c7_row18_col2, #T_bb4c7_row19_col2 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# </style>
# <table id="T_bb4c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb4c7_level0_col0" class="col_heading level0 col0" >tld</th>
#       <th id="T_bb4c7_level0_col1" class="col_heading level0 col1" >lang</th>
#       <th id="T_bb4c7_level0_col2" class="col_heading level0 col2" >P(lang|tld)</th>
#       <th id="T_bb4c7_level0_col3" class="col_heading level0 col3" >P(tld|lang)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb4c7_level0_row0" class="row_heading level0 row0" >1130</th>
#       <td id="T_bb4c7_row0_col0" class="data row0 col0" >fr</td>
#       <td id="T_bb4c7_row0_col1" class="data row0 col1" >fra_Latn</td>
#       <td id="T_bb4c7_row0_col2" class="data row0 col2" >0.762872</td>
#       <td id="T_bb4c7_row0_col3" class="data row0 col3" >0.289585</td>
#     </tr>
#     <tr>
#       <th id="T_bb4c7_level0_row1" class="row_heading level0 row1" >175</th>
#       <td id="T_bb4c7_row1_col0" class="data row1 col0" >be</td>
#       <td id="T_bb4c7_row1_col1" class="data row1 col1" >fra_Latn</td>
#       <td id="T_bb4c7_row1_col2" class="data row1 col2" >0.203617</td>
#       <td id="T_bb4c7_row1_col3" class="data row1 col3" >0.028187</td>
#     </tr>
#     <tr>
#       <th id="T_bb4c7_level0_row2" class="row_heading level0 row2" >497</th>
#       <td id="T_bb4c7_row2_col0" class="data row2 col0" >ch</td>
#       <td id="T_bb4c7_row2_col1" class="data row2 col1" >fra_Latn</td>
#       <td id="T_bb4c7_row2_col2" class="data row2 col2" >0.125561</td>
#       <td id="T_bb4c7_row2_col3" class="data row2 col3" >0.018092</td>
#     </tr>
#     <tr>
#       <th id="T_bb4c7_level0_row3" class="row_heading level0 row3" >394</th>
#       <td id="T_bb4c7_row3_col0" class="data row3 col0" >ca</td>
#       <td id="T_bb4c7_row3_col1" class="data row3 col1" >fra_Latn</td>
#       <td id="T_bb4c7_row3_col2" class="data row3 col2" >0.112544</td>
#       <td id="T_bb4c7_row3_col3" class="data row3 col3" >0.021847</td>
#     </tr>
#     <tr>
#       <th id="T_bb4c7_level0_row4" class="row_heading level0 row4" >2721</th>
#       <td id="T_bb4c7_row4_col0" class="data row4 col0" >tk</td>
#       <td id="T_bb4c7_row4_col1" class="data row4 col1" >fra_Latn</td>
#       <td id="T_bb4c7_row4_col2" class="data row4 col2" >0.087786</td>
#       <td id="T_bb4c7_row4_col3" class="data row4 col3" >0.000929</td>
#     </tr>
#     <tr>
#       <th id="T_bb4c7_level0_row5" class="row_heading level0 row5" >2400</th>
#       <td id="T_bb4c7_row5_col0" class="data row5 col0" >pro</td>
#       <td id="T_bb4c7_row5_col1" class="data row5 col1" >fra_Latn</td>
#       <td id="T_bb4c7_row5_col2" class="data row5 col2" >0.057971</td>
#       <td id="T_bb4c7_row5_col3" class="data row5 col3" >0.001131</td>
#     </tr>
#     <tr>
#       <th id="T_bb4c7_level0_row6" class="row_heading level0 row6" >1017</th>
#       <td id="T_bb4c7_row6_col0" class="data row6 col0" >eu</td>
#       <td id="T_bb4c7_row6_col1" class="data row6 col1" >fra_Latn</td>
#       <td id="T_bb4c7_row6_col2" class="data row6 col2" >0.055791</td>
#       <td id="T_bb4c7_row6_col3" class="data row6 col3" >0.008521</td>
#     </tr>
#     <tr>
#       <th id="T_bb4c7_level0_row7" class="row_heading level0 row7" >654</th>
#       <td id="T_bb4c7_row7_col0" class="data row7 col0" >co</td>
#       <td id="T_bb4c7_row7_col1" class="data row7 col1" >fra_Latn</td>
#       <td id="T_bb4c7_row7_col2" class="data row7 col2" >0.044724</td>
#       <td id="T_bb4c7_row7_col3" class="data row7 col3" >0.004159</td>
#     </tr>
#     <tr>
#       <th id="T_bb4c7_level0_row8" class="row_h
